# %%
import pandas
data = pandas.read_csv('ordata/or.occupation', delimiter='\t', index_col=False)
data.head()
# Out:
#   occupation_code  soc_code                  occupation_text  display_level  \
# 0             000         0                      All Workers              0
# 1             001  11101100                 Chief Executives              1
# 2             003  11102100  General and Operations Managers              1
# 3             007  11202100               Marketing Managers              1
# 4             008  11202200                   Sales Managers              1
#
#   selectable  sort_sequence
# 0          T              1
# 1          T              3
# 2          T              5
# 3          T              9
# 4          T             10

# %%
aggregates = data[data['display_level']==0]
jobs = data[data['display_level']==1]

# %%
jobs
# Out:
#     occupation_code  soc_code  \
# 1               001  11101100
# 2               003  11102100
# 3               007  11202100
# 4               008  11202200
# 5               009  11203100
# 6               010  11301100
# 7               011  11302100
# 8               012  11303100
# 9               013  11303101
# 10              014  11303102
# 11              022  11306100
# 12              028  11312100
# 13              029  11313100
# 14              034  11902100
# 15              036  11903200
# 16              037  11903300
# 17              041  11904100
# 18              043  11905100
# 19              047  11911100
# 20              052  11914100
# 21              053  11915100
# 22              05A  51906100
# 23              067  13102200
# 24              068  13102300
# 25              071  13103102
# 26              080  13105100
# 27              081  13107100
# 28              086  13108102
# 29              087  13111100
# 30              088  13112100
# ...

# %%
jobs[jobs['occupation_code'] == '009']
# Out:
#   occupation_code  soc_code                            occupation_text  \
# 5             009  11203100  Public Relations and Fundraising Managers
#
#    display_level selectable  sort_sequence
# 5              1          T             11
