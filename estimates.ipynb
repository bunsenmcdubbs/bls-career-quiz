# %%
import pandas
data = pandas.read_csv('ordata/or.estimate', delimiter='\t', index_col=False)
data
# Out:
#      estimate_code                                      estimate_text  \
# 0               64  Percent of workers, svp is short demonstration...
# 1               65  Percent of workers, svp is beyond short demons...
# 2               66  Percent of workers, svp is over 1 month, up to...
# 3               67  Percent of workers, svp is over 3 months, up t...
# 4               68  Percent of workers, svp is over 6 months, up t...
# 5               69  Percent of workers, svp is over 1 year, up to ...
# 6               70  Percent of workers, svp is over 2 years, up to...
# 7               71  Percent of workers, svp is over 4 years, up to...
# 8               72           Percent of workers, svp is over 10 years
# 9               75  Percent of workers, minimum education level is...
# 10              76  Percent of workers, minimum education level is...
# 11              77  Percent of workers, minimum education level is...
# ...

# %% [markdown]
# Scales

# %%
scales = {
    'minimum education level': (10, 16),
    '% literacy required': 16,
    '% pre-employment training required': 18,
    '% prior-work experience required': ,
    '% post-employment training required': '00122',
    '% sitting vs. standing/walking at will is allowed': '000139',
    '% reaching overhead': (142, 158),
    '% reaching at/below the shoulder': (159, 175),
    '% traditional keyboarding': (176, 181),
    '% touchpad keyboarding': (190, 194),
    'weight seldom carried': (239, 244),
    'weight occasionally carried': (246, 251),
    'weight frequently carried': (253, 258),
    'weight constantly carried': (259, 265),
    '% crawling': (267, 270),
    '% pushing/pulling with hands/arms': (281, 284),
    '% pushing/pulling with feet/legs': (295, 299),
    '% driving not required': '00311',
    '% foot/leg controls': (313, 329),
    
}

# %%
list('{:05d}'.format(x) for x in range(75,81))
# Out:
# ['00075', '00076', '00077', '00078', '00079', '00080']

# %% [markdown]
# Median and distribution

# %%
dists = {
    'days of pre-employment training': (101, 107),
    'days of prior work experience': (108, 114),
    'days of post-employment training': (116, 122),
    'hours of standing/walking': (125, 131),
    'hours of sitting': (132, 138),
    'pounds maximum weight lifted/carried': (233, 239),
    
}
